# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# [<img src="https://raw.githubusercontent.com/taehojo/taehojo.github.io/master/assets/images/linktocolab.png" align="left"/> ](https://colab.research.google.com/github/taehojo/deeplearning/blob/master/colab/ch19-colab.ipynb)

# %% [markdown]
# ## 3. 적대적 신경망 실행하기

# %% [markdown]
# ### 실습: GAN 모델 만들기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# 예제 파일에서 data 폴더 아래에 이미지가 저장될 gan_images 폴더가 함께 제공됩니다.
# 만약 이미지가 저장될 폴더가 없다면 아래 코드의 주석을 해제해 gan_images 폴더를 만듭니다.
# import os
# if not os.path.exists("./data/gan_images"):
#    os.makedirs("./data/gan_images")

# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("./data/gan_images/gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# 1/1 [==============================] - 0s 360ms/step
# epoch:0  d_loss:0.7298  g_loss:0.6021
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 18ms/step
# epoch:1  d_loss:0.5107  g_loss:0.3004
# 1/1 [==============================] - 0s 17ms/step
# epoch:2  d_loss:0.5400  g_loss:0.1447
# 1/1 [==============================] - 0s 20ms/step
# epoch:3  d_loss:0.5484  g_loss:0.1463
# 1/1 [==============================] - 0s 18ms/step
# epoch:4  d_loss:0.5238  g_loss:0.2329
# 1/1 [==============================] - 0s 20ms/step
# epoch:5  d_loss:0.4819  g_loss:0.4279
# 1/1 [==============================] - 0s 17ms/step
# epoch:6  d_loss:0.4623  g_loss:0.6474
# 1/1 [==============================] - 0s 18ms/step
# epoch:7  d_loss:0.4887  g_loss:0.7504
# 1/1 [==============================] - 0s 18ms/step
# epoch:8  d_loss:0.4739  g_loss:0.8181
# 1/1 [==============================] - 0s 19ms/step
# epoch:9  d_loss:0.5331  g_loss:0.6968
# 1/1 [==============================] - 0s 18ms/step
# epoch:10  d_loss:0.6117  g_loss:0.6178
# 1/1 [==============================] - 0s 18ms/step
# epoch:11  d_loss:0.5985  g_loss:0.6061
# 1/1 [==============================] - 0s 17ms/step
# epoch:12  d_loss:0.6891  g_loss:0.5540
# 1/1 [==============================] - 0s 19ms/step
# epoch:13  d_loss:0.6175  g_loss:0.5993
# 1/1 [==============================] - 0s 17ms/step
# epoch:14  d_loss:0.6555  g_loss:0.6173
# 1/1 [==============================] - 0s 18ms/step
# epoch:15  d_loss:0.5951  g_loss:0.6958
# 1/1 [==============================] - 0s 19ms/step
# epoch:16  d_loss:0.5634  g_loss:0.6945
# 1/1 [==============================] - 0s 21ms/step
# epoch:17  d_loss:0.5727  g_loss:0.6656
# 1/1 [==============================] - 0s 18ms/step
# epoch:18  d_loss:0.5791  g_loss:0.6348
# 1/1 [==============================] - 0s 20ms/step
# epoch:19  d_loss:0.5332  g_loss:0.6497
# 1/1 [==============================] - 0s 18ms/step
# epoch:20  d_loss:0.5383  g_loss:0.6597
# 1/1 [==============================] - 0s 18ms/step
# epoch:21  d_loss:0.5275  g_loss:0.6440
# 1/1 [==============================] - 0s 17ms/step
# epoch:22  d_loss:0.5226  g_loss:0.7267
# 1/1 [==============================] - 0s 18ms/step
# epoch:23  d_loss:0.4989  g_loss:0.7448
# 1/1 [==============================] - 0s 18ms/step
# epoch:24  d_loss:0.5401  g_loss:0.6545
# 1/1 [==============================] - 0s 17ms/step
# epoch:25  d_loss:0.5375  g_loss:0.7053
# 1/1 [==============================] - 0s 19ms/step
# epoch:26  d_loss:0.5243  g_loss:0.7281
# 1/1 [==============================] - 0s 17ms/step
# epoch:27  d_loss:0.5408  g_loss:0.7789
# 1/1 [==============================] - 0s 18ms/step
# epoch:28  d_loss:0.4650  g_loss:0.7419
# 1/1 [==============================] - 0s 18ms/step
# epoch:29  d_loss:0.5263  g_loss:0.7060
# 1/1 [==============================] - 0s 19ms/step
# epoch:30  d_loss:0.5045  g_loss:0.8131
# 1/1 [==============================] - 0s 18ms/step
# epoch:31  d_loss:0.5407  g_loss:0.7067
# 1/1 [==============================] - 0s 19ms/step
# epoch:32  d_loss:0.4969  g_loss:0.8750
# 1/1 [==============================] - 0s 19ms/step
# epoch:33  d_loss:0.4235  g_loss:0.9835
# 1/1 [==============================] - 0s 18ms/step
# epoch:34  d_loss:0.3893  g_loss:1.0870
# 1/1 [==============================] - 0s 19ms/step
# epoch:35  d_loss:0.4050  g_loss:1.1951
# 1/1 [==============================] - 0s 20ms/step
# epoch:36  d_loss:0.4898  g_loss:1.1537
# 1/1 [==============================] - 0s 19ms/step
# epoch:37  d_loss:0.3972  g_loss:1.0877
# 1/1 [==============================] - 0s 17ms/step
# epoch:38  d_loss:0.4934  g_loss:1.1360
# 1/1 [==============================] - 0s 18ms/step
# epoch:39  d_loss:0.3806  g_loss:1.3145
# 1/1 [==============================] - 0s 20ms/step
# epoch:40  d_loss:0.4174  g_loss:1.3318
# 1/1 [==============================] - 0s 18ms/step
# epoch:41  d_loss:0.4877  g_loss:1.3626
# 1/1 [==============================] - 0s 20ms/step
# epoch:42  d_loss:0.4666  g_loss:1.2268
# 1/1 [==============================] - 0s 20ms/step
# epoch:43  d_loss:0.4029  g_loss:1.3954
# 1/1 [==============================] - 0s 18ms/step
# epoch:44  d_loss:0.3001  g_loss:1.7640
# 1/1 [==============================] - 0s 18ms/step
# epoch:45  d_loss:0.2166  g_loss:2.1142
# 1/1 [==============================] - 0s 20ms/step
# epoch:46  d_loss:0.1926  g_loss:1.7954
# 1/1 [==============================] - 0s 19ms/step
# epoch:47  d_loss:0.1358  g_loss:1.4783
# 1/1 [==============================] - 0s 19ms/step
# epoch:48  d_loss:0.1127  g_loss:1.8242
# 1/1 [==============================] - 0s 20ms/step
# epoch:49  d_loss:0.2081  g_loss:2.1019
# 1/1 [==============================] - 0s 20ms/step
# epoch:50  d_loss:0.2036  g_loss:2.5076
# 1/1 [==============================] - 0s 19ms/step
# epoch:51  d_loss:0.3584  g_loss:2.5709
# 1/1 [==============================] - 0s 18ms/step
# epoch:52  d_loss:0.1881  g_loss:2.6272
# 1/1 [==============================] - 0s 19ms/step
# epoch:53  d_loss:0.7572  g_loss:1.3371
# 1/1 [==============================] - 0s 20ms/step
# epoch:54  d_loss:0.6767  g_loss:1.6675
# 1/1 [==============================] - 0s 19ms/step
# epoch:55  d_loss:0.3778  g_loss:2.3311
# 1/1 [==============================] - 0s 18ms/step
# epoch:56  d_loss:0.4220  g_loss:3.3144
# 1/1 [==============================] - 0s 20ms/step
# epoch:57  d_loss:0.6611  g_loss:2.9755
# 1/1 [==============================] - 0s 19ms/step
# epoch:58  d_loss:0.6116  g_loss:2.2850
# 1/1 [==============================] - 0s 17ms/step
# epoch:59  d_loss:0.6278  g_loss:1.7193
# 1/1 [==============================] - 0s 18ms/step
# epoch:60  d_loss:0.2941  g_loss:3.0453
# 1/1 [==============================] - 0s 18ms/step
# epoch:61  d_loss:0.2902  g_loss:3.6941
# 1/1 [==============================] - 0s 18ms/step
# epoch:62  d_loss:0.4696  g_loss:3.3326
# 1/1 [==============================] - 0s 18ms/step
# epoch:63  d_loss:0.3524  g_loss:2.4389
# 1/1 [==============================] - 0s 19ms/step
# epoch:64  d_loss:0.3631  g_loss:1.9881
# 1/1 [==============================] - 0s 20ms/step
# epoch:65  d_loss:0.4566  g_loss:1.7397
# 1/1 [==============================] - 0s 18ms/step
# epoch:66  d_loss:0.4402  g_loss:2.2159
# 1/1 [==============================] - 0s 20ms/step
# epoch:67  d_loss:0.5295  g_loss:1.8407
# 1/1 [==============================] - 0s 18ms/step
# epoch:68  d_loss:0.5517  g_loss:1.5065
# 1/1 [==============================] - 0s 18ms/step
# epoch:69  d_loss:0.6069  g_loss:1.0418
# 1/1 [==============================] - 0s 18ms/step
# epoch:70  d_loss:0.8996  g_loss:1.1781
# 1/1 [==============================] - 0s 18ms/step
# epoch:71  d_loss:0.4892  g_loss:1.9074
# 1/1 [==============================] - 0s 18ms/step
# epoch:72  d_loss:0.4498  g_loss:2.5292
# 1/1 [==============================] - 0s 19ms/step
# epoch:73  d_loss:0.4871  g_loss:1.8037
# 1/1 [==============================] - 0s 19ms/step
# epoch:74  d_loss:0.3370  g_loss:1.6420
# 1/1 [==============================] - 0s 19ms/step
# epoch:75  d_loss:0.2444  g_loss:1.9981
# 1/1 [==============================] - 0s 19ms/step
# epoch:76  d_loss:0.1591  g_loss:2.4280
# 1/1 [==============================] - 0s 17ms/step
# epoch:77  d_loss:0.0967  g_loss:3.4570
# 1/1 [==============================] - 0s 17ms/step
# epoch:78  d_loss:0.0927  g_loss:4.3366
# 1/1 [==============================] - 0s 19ms/step
# epoch:79  d_loss:0.1873  g_loss:4.1987
# 1/1 [==============================] - 0s 19ms/step
# epoch:80  d_loss:0.3104  g_loss:3.6047
# 1/1 [==============================] - 0s 19ms/step
# epoch:81  d_loss:0.4830  g_loss:3.1855
# 1/1 [==============================] - 0s 19ms/step
# epoch:82  d_loss:0.7515  g_loss:2.9062
# 1/1 [==============================] - 0s 20ms/step
# epoch:83  d_loss:0.9741  g_loss:2.9186
# 1/1 [==============================] - 0s 19ms/step
# epoch:84  d_loss:0.9152  g_loss:3.0677
# 1/1 [==============================] - 0s 18ms/step
# epoch:85  d_loss:0.8012  g_loss:3.1962
# 1/1 [==============================] - 0s 18ms/step
# epoch:86  d_loss:1.0457  g_loss:2.6034
# 1/1 [==============================] - 0s 21ms/step
# epoch:87  d_loss:0.7768  g_loss:1.8493
# 1/1 [==============================] - 0s 19ms/step
# epoch:88  d_loss:0.7470  g_loss:1.8611
# 1/1 [==============================] - 0s 19ms/step
# epoch:89  d_loss:0.8467  g_loss:1.7225
# 1/1 [==============================] - 0s 18ms/step
# epoch:90  d_loss:0.6182  g_loss:1.9325
# 1/1 [==============================] - 0s 21ms/step
# epoch:91  d_loss:0.4795  g_loss:2.0030
# 1/1 [==============================] - 0s 19ms/step
# epoch:92  d_loss:0.4371  g_loss:2.1764
# 1/1 [==============================] - 0s 19ms/step
# epoch:93  d_loss:0.4133  g_loss:2.0609
# 1/1 [==============================] - 0s 19ms/step
# epoch:94  d_loss:0.3217  g_loss:1.8696
# 1/1 [==============================] - 0s 19ms/step
# epoch:95  d_loss:0.4725  g_loss:1.7028
# 1/1 [==============================] - 0s 18ms/step
# epoch:96  d_loss:0.2512  g_loss:1.6916
# 1/1 [==============================] - 0s 19ms/step
# epoch:97  d_loss:0.4586  g_loss:1.4340
# 1/1 [==============================] - 0s 17ms/step
# epoch:98  d_loss:0.4989  g_loss:1.7999
# 1/1 [==============================] - 0s 19ms/step
# epoch:99  d_loss:0.5986  g_loss:1.6299
# 1/1 [==============================] - 0s 18ms/step
# epoch:100  d_loss:0.3696  g_loss:1.7303
# 1/1 [==============================] - 0s 18ms/step
# epoch:101  d_loss:0.3323  g_loss:1.9508
# 1/1 [==============================] - 0s 19ms/step
# epoch:102  d_loss:0.5147  g_loss:1.4228
# 1/1 [==============================] - 0s 18ms/step
# epoch:103  d_loss:0.5699  g_loss:1.4184
# 1/1 [==============================] - 0s 18ms/step
# epoch:104  d_loss:0.3010  g_loss:1.2704
# 1/1 [==============================] - 0s 18ms/step
# epoch:105  d_loss:0.4972  g_loss:1.3764
# 1/1 [==============================] - 0s 19ms/step
# epoch:106  d_loss:0.5022  g_loss:1.3239
# 1/1 [==============================] - 0s 19ms/step
# epoch:107  d_loss:0.4275  g_loss:1.4487
# 1/1 [==============================] - 0s 20ms/step
# epoch:108  d_loss:0.4876  g_loss:1.4002
# 1/1 [==============================] - 0s 17ms/step
# epoch:109  d_loss:0.3651  g_loss:1.5354
# 1/1 [==============================] - 0s 19ms/step
# epoch:110  d_loss:0.5062  g_loss:1.3671
# 1/1 [==============================] - 0s 18ms/step
# epoch:111  d_loss:0.4743  g_loss:1.2792
# 1/1 [==============================] - 0s 18ms/step
# epoch:112  d_loss:0.5258  g_loss:1.5208
# 1/1 [==============================] - 0s 19ms/step
# epoch:113  d_loss:0.5014  g_loss:1.2250
# 1/1 [==============================] - 0s 19ms/step
# epoch:114  d_loss:0.5778  g_loss:1.1804
# 1/1 [==============================] - 0s 19ms/step
# epoch:115  d_loss:0.5250  g_loss:1.3098
# 1/1 [==============================] - 0s 20ms/step
# epoch:116  d_loss:0.5839  g_loss:1.5183
# 1/1 [==============================] - 0s 17ms/step
# epoch:117  d_loss:0.4964  g_loss:1.6755
# 1/1 [==============================] - 0s 19ms/step
# epoch:118  d_loss:0.4898  g_loss:1.7748
# 1/1 [==============================] - 0s 18ms/step
# epoch:119  d_loss:0.4496  g_loss:1.5766
# 1/1 [==============================] - 0s 20ms/step
# epoch:120  d_loss:0.6286  g_loss:1.6250
# 1/1 [==============================] - 0s 18ms/step
# epoch:121  d_loss:0.4771  g_loss:1.5958
# 1/1 [==============================] - 0s 19ms/step
# epoch:122  d_loss:0.4417  g_loss:1.5382
# 1/1 [==============================] - 0s 19ms/step
# epoch:123  d_loss:0.5017  g_loss:1.7705
# 1/1 [==============================] - 0s 19ms/step
# epoch:124  d_loss:0.4046  g_loss:2.0131
# 1/1 [==============================] - 0s 20ms/step
# epoch:125  d_loss:0.3228  g_loss:2.2403
# 1/1 [==============================] - 0s 19ms/step
# epoch:126  d_loss:0.5350  g_loss:2.1346
# 1/1 [==============================] - 0s 18ms/step
# epoch:127  d_loss:0.5082  g_loss:1.8852
# 1/1 [==============================] - 0s 18ms/step
# epoch:128  d_loss:0.5257  g_loss:1.8842
# 1/1 [==============================] - 0s 19ms/step
# epoch:129  d_loss:0.5607  g_loss:1.7890
# 1/1 [==============================] - 0s 18ms/step
# epoch:130  d_loss:0.5324  g_loss:1.7191
# 1/1 [==============================] - 0s 18ms/step
# epoch:131  d_loss:0.3874  g_loss:2.0465
# 1/1 [==============================] - 0s 18ms/step
# epoch:132  d_loss:0.5510  g_loss:1.9619
# 1/1 [==============================] - 0s 18ms/step
# epoch:133  d_loss:0.6559  g_loss:1.6943
# 1/1 [==============================] - 0s 18ms/step
# epoch:134  d_loss:0.5645  g_loss:1.6984
# 1/1 [==============================] - 0s 20ms/step
# epoch:135  d_loss:0.6882  g_loss:1.4488
# 1/1 [==============================] - 0s 19ms/step
# epoch:136  d_loss:0.6043  g_loss:1.4520
# 1/1 [==============================] - 0s 18ms/step
# epoch:137  d_loss:0.6901  g_loss:1.2651
# 1/1 [==============================] - 0s 18ms/step
# epoch:138  d_loss:0.5020  g_loss:1.5394
# 1/1 [==============================] - 0s 19ms/step
# epoch:139  d_loss:0.4543  g_loss:1.6286
# 1/1 [==============================] - 0s 18ms/step
# epoch:140  d_loss:0.5558  g_loss:1.8084
# 1/1 [==============================] - 0s 19ms/step
# epoch:141  d_loss:0.5278  g_loss:1.7471
# 1/1 [==============================] - 0s 19ms/step
# epoch:142  d_loss:0.4654  g_loss:1.4232
# 1/1 [==============================] - 0s 18ms/step
# epoch:143  d_loss:0.5261  g_loss:1.4265
# 1/1 [==============================] - 0s 19ms/step
# epoch:144  d_loss:0.4345  g_loss:1.3645
# 1/1 [==============================] - 0s 19ms/step
# epoch:145  d_loss:0.4466  g_loss:1.3368
# 1/1 [==============================] - 0s 18ms/step
# epoch:146  d_loss:0.5931  g_loss:1.2630
# 1/1 [==============================] - 0s 18ms/step
# epoch:147  d_loss:0.4755  g_loss:1.4673
# 1/1 [==============================] - 0s 19ms/step
# epoch:148  d_loss:0.3515  g_loss:1.7420
# 1/1 [==============================] - 0s 20ms/step
# epoch:149  d_loss:0.3097  g_loss:2.0890
# 1/1 [==============================] - 0s 17ms/step
# epoch:150  d_loss:0.3506  g_loss:2.0471
# 1/1 [==============================] - 0s 18ms/step
# epoch:151  d_loss:0.5353  g_loss:1.6427
# 1/1 [==============================] - 0s 19ms/step
# epoch:152  d_loss:0.3916  g_loss:1.4532
# 1/1 [==============================] - 0s 18ms/step
# epoch:153  d_loss:0.3914  g_loss:1.6075
# 1/1 [==============================] - 0s 18ms/step
# epoch:154  d_loss:0.4378  g_loss:1.7078
# 1/1 [==============================] - 0s 19ms/step
# epoch:155  d_loss:0.3927  g_loss:1.9675
# 1/1 [==============================] - 0s 17ms/step
# epoch:156  d_loss:0.4110  g_loss:2.0951
# 1/1 [==============================] - 0s 18ms/step
# epoch:157  d_loss:0.4816  g_loss:2.0794
# 1/1 [==============================] - 0s 19ms/step
# epoch:158  d_loss:0.4114  g_loss:2.5450
# 1/1 [==============================] - 0s 18ms/step
# epoch:159  d_loss:0.3872  g_loss:2.1890
# 1/1 [==============================] - 0s 18ms/step
# epoch:160  d_loss:0.4956  g_loss:1.8543
# 1/1 [==============================] - 0s 18ms/step
# epoch:161  d_loss:0.4432  g_loss:1.5622
# 1/1 [==============================] - 0s 18ms/step
# epoch:162  d_loss:0.4748  g_loss:1.4343
# 1/1 [==============================] - 0s 19ms/step
# epoch:163  d_loss:0.5256  g_loss:1.7654
# 1/1 [==============================] - 0s 19ms/step
# epoch:164  d_loss:0.4492  g_loss:2.4016
# 1/1 [==============================] - 0s 19ms/step
# epoch:165  d_loss:0.6156  g_loss:1.7000
# 1/1 [==============================] - 0s 17ms/step
# epoch:166  d_loss:0.4578  g_loss:1.9912
# 1/1 [==============================] - 0s 19ms/step
# epoch:167  d_loss:0.6491  g_loss:1.8086
# 1/1 [==============================] - 0s 18ms/step
# epoch:168  d_loss:0.4667  g_loss:1.8292
# 1/1 [==============================] - 0s 18ms/step
# epoch:169  d_loss:0.5305  g_loss:1.6615
# 1/1 [==============================] - 0s 18ms/step
# epoch:170  d_loss:0.4874  g_loss:2.1746
# 1/1 [==============================] - 0s 18ms/step
# epoch:171  d_loss:0.5798  g_loss:1.7120
# 1/1 [==============================] - 0s 19ms/step
# epoch:172  d_loss:0.4884  g_loss:1.7616
# 1/1 [==============================] - 0s 18ms/step
# epoch:173  d_loss:0.7202  g_loss:1.7504
# 1/1 [==============================] - 0s 20ms/step
# epoch:174  d_loss:0.7052  g_loss:1.7001
# 1/1 [==============================] - 0s 18ms/step
# epoch:175  d_loss:0.6149  g_loss:1.7448
# 1/1 [==============================] - 0s 19ms/step
# epoch:176  d_loss:0.5849  g_loss:1.8610
# 1/1 [==============================] - 0s 18ms/step
# epoch:177  d_loss:0.6275  g_loss:1.7266
# 1/1 [==============================] - 0s 18ms/step
# epoch:178  d_loss:0.7557  g_loss:1.6757
# 1/1 [==============================] - 0s 18ms/step
# epoch:179  d_loss:0.6382  g_loss:1.2480
# 1/1 [==============================] - 0s 17ms/step
# epoch:180  d_loss:0.6068  g_loss:1.2756
# 1/1 [==============================] - 0s 18ms/step
# epoch:181  d_loss:0.4526  g_loss:1.3639
# 1/1 [==============================] - 0s 19ms/step
# epoch:182  d_loss:0.5048  g_loss:1.5485
# 1/1 [==============================] - 0s 18ms/step
# epoch:183  d_loss:0.4311  g_loss:1.7214
# 1/1 [==============================] - 0s 17ms/step
# epoch:184  d_loss:0.4313  g_loss:1.5963
# 1/1 [==============================] - 0s 18ms/step
# epoch:185  d_loss:0.3658  g_loss:1.7912
# 1/1 [==============================] - 0s 19ms/step
# epoch:186  d_loss:0.4684  g_loss:1.7085
# 1/1 [==============================] - 0s 18ms/step
# epoch:187  d_loss:0.4276  g_loss:1.9732
# 1/1 [==============================] - 0s 19ms/step
# epoch:188  d_loss:0.4111  g_loss:2.0094
# 1/1 [==============================] - 0s 17ms/step
# epoch:189  d_loss:0.3418  g_loss:2.1156
# 1/1 [==============================] - 0s 20ms/step
# epoch:190  d_loss:0.3395  g_loss:1.9530
# 1/1 [==============================] - 0s 17ms/step
# epoch:191  d_loss:0.4157  g_loss:1.9110
# 1/1 [==============================] - 0s 18ms/step
# epoch:192  d_loss:0.3237  g_loss:1.9390
# 1/1 [==============================] - 0s 19ms/step
# epoch:193  d_loss:0.3497  g_loss:2.1135
# 1/1 [==============================] - 0s 18ms/step
# epoch:194  d_loss:0.3214  g_loss:1.8095
# 1/1 [==============================] - 0s 19ms/step
# epoch:195  d_loss:0.3360  g_loss:2.2650
# 1/1 [==============================] - 0s 19ms/step
# epoch:196  d_loss:0.3228  g_loss:2.3478
# 1/1 [==============================] - 0s 19ms/step
# epoch:197  d_loss:0.3651  g_loss:2.3756
# 1/1 [==============================] - 0s 18ms/step
# epoch:198  d_loss:0.2847  g_loss:2.8082
# 1/1 [==============================] - 0s 19ms/step
# epoch:199  d_loss:0.2624  g_loss:2.2326
# 1/1 [==============================] - 0s 19ms/step
# epoch:200  d_loss:0.3927  g_loss:2.0010
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# epoch:201  d_loss:0.3337  g_loss:2.0144
# 1/1 [==============================] - 0s 18ms/step
# epoch:202  d_loss:0.4425  g_loss:2.0484
# 1/1 [==============================] - 0s 17ms/step
# epoch:203  d_loss:0.3910  g_loss:2.2268
# 1/1 [==============================] - 0s 18ms/step
# epoch:204  d_loss:0.3659  g_loss:2.3142
# 1/1 [==============================] - 0s 17ms/step
# epoch:205  d_loss:0.3436  g_loss:2.6290
# 1/1 [==============================] - 0s 19ms/step
# epoch:206  d_loss:0.3654  g_loss:2.3862
# 1/1 [==============================] - 0s 19ms/step
# epoch:207  d_loss:0.3116  g_loss:2.5675
# 1/1 [==============================] - 0s 17ms/step
# epoch:208  d_loss:0.3563  g_loss:2.3403
# 1/1 [==============================] - 0s 19ms/step
# epoch:209  d_loss:0.4562  g_loss:2.6811
# 1/1 [==============================] - 0s 22ms/step
# epoch:210  d_loss:0.4312  g_loss:2.0816
# 1/1 [==============================] - 0s 19ms/step
# epoch:211  d_loss:0.3931  g_loss:1.9815
# 1/1 [==============================] - 0s 19ms/step
# epoch:212  d_loss:0.4054  g_loss:2.2587
# 1/1 [==============================] - 0s 19ms/step
# epoch:213  d_loss:0.4161  g_loss:2.8258
# 1/1 [==============================] - 0s 21ms/step
# epoch:214  d_loss:0.3547  g_loss:2.5034
# 1/1 [==============================] - 0s 18ms/step
# epoch:215  d_loss:0.2973  g_loss:2.4782
# 1/1 [==============================] - 0s 18ms/step
# epoch:216  d_loss:0.3944  g_loss:3.1196
# 1/1 [==============================] - 0s 18ms/step
# epoch:217  d_loss:0.4144  g_loss:2.6953
# 1/1 [==============================] - 0s 18ms/step
# epoch:218  d_loss:0.2913  g_loss:3.2751
# 1/1 [==============================] - 0s 18ms/step
# epoch:219  d_loss:0.5286  g_loss:3.0264
# 1/1 [==============================] - 0s 20ms/step
# epoch:220  d_loss:0.5354  g_loss:2.3088
# 1/1 [==============================] - 0s 19ms/step
# epoch:221  d_loss:0.4450  g_loss:2.6331
# 1/1 [==============================] - 0s 18ms/step
# epoch:222  d_loss:0.3652  g_loss:3.2680
# 1/1 [==============================] - 0s 23ms/step
# epoch:223  d_loss:0.4205  g_loss:2.9152
# 1/1 [==============================] - 0s 19ms/step
# epoch:224  d_loss:0.5090  g_loss:2.7057
# 1/1 [==============================] - 0s 19ms/step
# epoch:225  d_loss:0.4372  g_loss:2.5307
# 1/1 [==============================] - 0s 21ms/step
# epoch:226  d_loss:0.4143  g_loss:2.5386
# 1/1 [==============================] - 0s 19ms/step
# epoch:227  d_loss:0.2980  g_loss:2.5596
# 1/1 [==============================] - 0s 18ms/step
# epoch:228  d_loss:0.3060  g_loss:2.7794
# 1/1 [==============================] - 0s 18ms/step
# epoch:229  d_loss:0.4937  g_loss:2.3629
# 1/1 [==============================] - 0s 19ms/step
# epoch:230  d_loss:0.5153  g_loss:2.2362
# 1/1 [==============================] - 0s 18ms/step
# epoch:231  d_loss:0.4616  g_loss:2.0783
# 1/1 [==============================] - 0s 17ms/step
# epoch:232  d_loss:0.5906  g_loss:2.4481
# 1/1 [==============================] - 0s 18ms/step
# epoch:233  d_loss:0.4389  g_loss:2.0156
# 1/1 [==============================] - 0s 17ms/step
# epoch:234  d_loss:0.5074  g_loss:2.4152
# 1/1 [==============================] - 0s 19ms/step
# epoch:235  d_loss:0.4452  g_loss:2.3331
# 1/1 [==============================] - 0s 17ms/step
# epoch:236  d_loss:0.5197  g_loss:1.9818
# 1/1 [==============================] - 0s 19ms/step
# epoch:237  d_loss:0.4676  g_loss:2.3472
# 1/1 [==============================] - 0s 17ms/step
# epoch:238  d_loss:0.3930  g_loss:2.7401
# 1/1 [==============================] - 0s 18ms/step
# epoch:239  d_loss:0.4008  g_loss:2.7244
# 1/1 [==============================] - 0s 19ms/step
# epoch:240  d_loss:0.3140  g_loss:2.5286
# 1/1 [==============================] - 0s 18ms/step
# epoch:241  d_loss:0.2569  g_loss:2.7136
# 1/1 [==============================] - 0s 18ms/step
# epoch:242  d_loss:0.2252  g_loss:3.0092
# 1/1 [==============================] - 0s 18ms/step
# epoch:243  d_loss:0.1889  g_loss:3.5756
# 1/1 [==============================] - 0s 18ms/step
# epoch:244  d_loss:0.3153  g_loss:3.2465
# 1/1 [==============================] - 0s 19ms/step
# epoch:245  d_loss:0.2063  g_loss:3.4590
# 1/1 [==============================] - 0s 18ms/step
# epoch:246  d_loss:0.2427  g_loss:3.3853
# 1/1 [==============================] - 0s 19ms/step
# epoch:247  d_loss:0.3776  g_loss:3.3355
# 1/1 [==============================] - 0s 18ms/step
# epoch:248  d_loss:0.3621  g_loss:2.5979
# 1/1 [==============================] - 0s 17ms/step
# epoch:249  d_loss:0.2530  g_loss:2.8069
# 1/1 [==============================] - 0s 17ms/step
# epoch:250  d_loss:0.3604  g_loss:2.6429
# 1/1 [==============================] - 0s 19ms/step
# epoch:251  d_loss:0.3536  g_loss:3.3540
# 1/1 [==============================] - 0s 19ms/step
# epoch:252  d_loss:0.3112  g_loss:3.0345
# 1/1 [==============================] - 0s 18ms/step
# epoch:253  d_loss:0.2593  g_loss:2.9881
# 1/1 [==============================] - 0s 19ms/step
# epoch:254  d_loss:0.4759  g_loss:2.3323
# 1/1 [==============================] - 0s 19ms/step
# epoch:255  d_loss:0.3279  g_loss:2.3078
# 1/1 [==============================] - 0s 16ms/step
# epoch:256  d_loss:0.4119  g_loss:2.4215
# 1/1 [==============================] - 0s 18ms/step
# epoch:257  d_loss:0.2914  g_loss:2.9432
# 1/1 [==============================] - 0s 19ms/step
# epoch:258  d_loss:0.3537  g_loss:2.9652
# 1/1 [==============================] - 0s 19ms/step
# epoch:259  d_loss:0.4540  g_loss:2.3731
# 1/1 [==============================] - 0s 19ms/step
# epoch:260  d_loss:0.3832  g_loss:2.3244
# 1/1 [==============================] - 0s 18ms/step
# epoch:261  d_loss:0.3905  g_loss:2.1530
# 1/1 [==============================] - 0s 18ms/step
# epoch:262  d_loss:0.4848  g_loss:2.4004
# 1/1 [==============================] - 0s 18ms/step
# epoch:263  d_loss:0.3741  g_loss:2.6796
# 1/1 [==============================] - 0s 19ms/step
# epoch:264  d_loss:0.5307  g_loss:2.2766
# 1/1 [==============================] - 0s 17ms/step
# epoch:265  d_loss:0.3948  g_loss:2.3853
# 1/1 [==============================] - 0s 18ms/step
# epoch:266  d_loss:0.5796  g_loss:2.1411
# 1/1 [==============================] - 0s 18ms/step
# epoch:267  d_loss:0.6450  g_loss:1.7547
# 1/1 [==============================] - 0s 17ms/step
# epoch:268  d_loss:0.6720  g_loss:1.7787
# 1/1 [==============================] - 0s 18ms/step
# epoch:269  d_loss:0.4859  g_loss:2.0878
# 1/1 [==============================] - 0s 19ms/step
# epoch:270  d_loss:0.4683  g_loss:2.3786
# 1/1 [==============================] - 0s 19ms/step
# epoch:271  d_loss:0.5395  g_loss:2.0897
# 1/1 [==============================] - 0s 19ms/step
# epoch:272  d_loss:0.5354  g_loss:2.1309
# 1/1 [==============================] - 0s 19ms/step
# epoch:273  d_loss:0.5048  g_loss:1.9116
# 1/1 [==============================] - 0s 18ms/step
# epoch:274  d_loss:0.4352  g_loss:2.3942
# 1/1 [==============================] - 0s 18ms/step
# epoch:275  d_loss:0.6244  g_loss:1.5375
# 1/1 [==============================] - 0s 19ms/step
# epoch:276  d_loss:0.5740  g_loss:1.2093
# 1/1 [==============================] - 0s 18ms/step
# epoch:277  d_loss:0.5069  g_loss:1.6008
# 1/1 [==============================] - 0s 19ms/step
# epoch:278  d_loss:0.5748  g_loss:1.9106
# 1/1 [==============================] - 0s 19ms/step
# epoch:279  d_loss:0.6452  g_loss:1.7716
# 1/1 [==============================] - 0s 19ms/step
# epoch:280  d_loss:0.4805  g_loss:2.1282
# 1/1 [==============================] - 0s 17ms/step
# epoch:281  d_loss:0.5338  g_loss:2.1586
# 1/1 [==============================] - 0s 18ms/step
# epoch:282  d_loss:0.5692  g_loss:1.8812
# 1/1 [==============================] - 0s 17ms/step
# epoch:283  d_loss:0.4644  g_loss:1.8631
# 1/1 [==============================] - 0s 19ms/step
# epoch:284  d_loss:0.3867  g_loss:1.9519
# 1/1 [==============================] - 0s 17ms/step
# epoch:285  d_loss:0.4143  g_loss:1.9408
# 1/1 [==============================] - 0s 17ms/step
# epoch:286  d_loss:0.3155  g_loss:2.1808
# 1/1 [==============================] - 0s 19ms/step
# epoch:287  d_loss:0.4003  g_loss:2.0397
# 1/1 [==============================] - 0s 18ms/step
# epoch:288  d_loss:0.3714  g_loss:1.8889
# 1/1 [==============================] - 0s 19ms/step
# epoch:289  d_loss:0.3022  g_loss:2.2812
# 1/1 [==============================] - 0s 18ms/step
# epoch:290  d_loss:0.3469  g_loss:2.2672
# 1/1 [==============================] - 0s 18ms/step
# epoch:291  d_loss:0.4279  g_loss:2.5260
# 1/1 [==============================] - 0s 20ms/step
# epoch:292  d_loss:0.4169  g_loss:2.3359
# 1/1 [==============================] - 0s 17ms/step
# epoch:293  d_loss:0.4365  g_loss:2.1117
# 1/1 [==============================] - 0s 18ms/step
# epoch:294  d_loss:0.3970  g_loss:2.6158
# 1/1 [==============================] - 0s 18ms/step
# epoch:295  d_loss:0.3354  g_loss:2.8055
# 1/1 [==============================] - 0s 18ms/step
# epoch:296  d_loss:0.4682  g_loss:3.4202
# 1/1 [==============================] - 0s 17ms/step
# epoch:297  d_loss:0.4187  g_loss:2.7126
# 1/1 [==============================] - 0s 19ms/step
# epoch:298  d_loss:0.3443  g_loss:2.5690
# 1/1 [==============================] - 0s 22ms/step
# epoch:299  d_loss:0.4097  g_loss:2.5040
# 1/1 [==============================] - 0s 19ms/step
# epoch:300  d_loss:0.3180  g_loss:2.0697
# 1/1 [==============================] - 0s 22ms/step
# epoch:301  d_loss:0.2286  g_loss:2.1705
# 1/1 [==============================] - 0s 21ms/step
# epoch:302  d_loss:0.3124  g_loss:2.6723
# 1/1 [==============================] - 0s 18ms/step
# epoch:303  d_loss:0.3094  g_loss:2.7712
# 1/1 [==============================] - 0s 17ms/step
# epoch:304  d_loss:0.4266  g_loss:3.1597
# 1/1 [==============================] - 0s 20ms/step
# epoch:305  d_loss:0.2873  g_loss:3.5620
# 1/1 [==============================] - 0s 18ms/step
# epoch:306  d_loss:0.2738  g_loss:3.7268
# 1/1 [==============================] - 0s 18ms/step
# epoch:307  d_loss:0.3865  g_loss:2.9601
# 1/1 [==============================] - 0s 18ms/step
# epoch:308  d_loss:0.2135  g_loss:2.8415
# 1/1 [==============================] - 0s 18ms/step
# epoch:309  d_loss:0.2856  g_loss:2.9663
# 1/1 [==============================] - 0s 17ms/step
# epoch:310  d_loss:0.2928  g_loss:2.7338
# 1/1 [==============================] - 0s 18ms/step
# epoch:311  d_loss:0.3309  g_loss:3.0618
# 1/1 [==============================] - 0s 19ms/step
# epoch:312  d_loss:0.4376  g_loss:2.4050
# 1/1 [==============================] - 0s 17ms/step
# epoch:313  d_loss:0.4546  g_loss:2.3081
# 1/1 [==============================] - 0s 18ms/step
# epoch:314  d_loss:0.3475  g_loss:2.7741
# 1/1 [==============================] - 0s 20ms/step
# epoch:315  d_loss:0.3421  g_loss:2.7449
# 1/1 [==============================] - 0s 18ms/step
# epoch:316  d_loss:0.3822  g_loss:3.2145
# 1/1 [==============================] - 0s 18ms/step
# epoch:317  d_loss:0.2708  g_loss:3.3729
# 1/1 [==============================] - 0s 18ms/step
# epoch:318  d_loss:0.2944  g_loss:2.9801
# 1/1 [==============================] - 0s 19ms/step
# epoch:319  d_loss:0.4976  g_loss:2.0671
# 1/1 [==============================] - 0s 18ms/step
# epoch:320  d_loss:0.2315  g_loss:2.4909
# 1/1 [==============================] - 0s 18ms/step
# epoch:321  d_loss:0.1881  g_loss:2.8582
# 1/1 [==============================] - 0s 16ms/step
# epoch:322  d_loss:0.2679  g_loss:3.5060
# 1/1 [==============================] - 0s 17ms/step
# epoch:323  d_loss:0.3194  g_loss:2.9286
# 1/1 [==============================] - 0s 18ms/step
# epoch:324  d_loss:0.4162  g_loss:2.9051
# 1/1 [==============================] - 0s 17ms/step
# epoch:325  d_loss:0.4125  g_loss:2.5954
# 1/1 [==============================] - 0s 18ms/step
# epoch:326  d_loss:0.3358  g_loss:2.3236
# 1/1 [==============================] - 0s 18ms/step
# epoch:327  d_loss:0.2533  g_loss:2.8904
# 1/1 [==============================] - 0s 17ms/step
# epoch:328  d_loss:0.4667  g_loss:2.0862
# 1/1 [==============================] - 0s 18ms/step
# epoch:329  d_loss:0.3110  g_loss:2.3109
# 1/1 [==============================] - 0s 19ms/step
# epoch:330  d_loss:0.3722  g_loss:2.2976
# 1/1 [==============================] - 0s 18ms/step
# epoch:331  d_loss:0.3522  g_loss:2.4868
# 1/1 [==============================] - 0s 18ms/step
# epoch:332  d_loss:0.2342  g_loss:2.5360
# 1/1 [==============================] - 0s 18ms/step
# epoch:333  d_loss:0.2256  g_loss:2.7729
# 1/1 [==============================] - 0s 18ms/step
# epoch:334  d_loss:0.2886  g_loss:2.7189
# 1/1 [==============================] - 0s 19ms/step
# epoch:335  d_loss:0.3737  g_loss:2.3527
# 1/1 [==============================] - 0s 18ms/step
# epoch:336  d_loss:0.2646  g_loss:2.6198
# 1/1 [==============================] - 0s 19ms/step
# epoch:337  d_loss:0.3318  g_loss:2.3675
# 1/1 [==============================] - 0s 19ms/step
# epoch:338  d_loss:0.2389  g_loss:3.3431
# 1/1 [==============================] - 0s 17ms/step
# epoch:339  d_loss:0.3248  g_loss:2.8069
# 1/1 [==============================] - 0s 19ms/step
# epoch:340  d_loss:0.2889  g_loss:2.5728
# 1/1 [==============================] - 0s 18ms/step
# epoch:341  d_loss:0.3234  g_loss:2.6159
# 1/1 [==============================] - 0s 17ms/step
# epoch:342  d_loss:0.3066  g_loss:2.3064
# 1/1 [==============================] - 0s 18ms/step
# epoch:343  d_loss:0.2736  g_loss:3.2548
# 1/1 [==============================] - 0s 19ms/step
# epoch:344  d_loss:0.4714  g_loss:2.3048
# 1/1 [==============================] - 0s 20ms/step
# epoch:345  d_loss:0.2541  g_loss:2.7005
# 1/1 [==============================] - 0s 18ms/step
# epoch:346  d_loss:0.2300  g_loss:2.2425
# 1/1 [==============================] - 0s 19ms/step
# epoch:347  d_loss:0.2773  g_loss:2.7603
# 1/1 [==============================] - 0s 20ms/step
# epoch:348  d_loss:0.4215  g_loss:2.2812
# 1/1 [==============================] - 0s 18ms/step
# epoch:349  d_loss:0.4069  g_loss:2.5793
# 1/1 [==============================] - 0s 17ms/step
# epoch:350  d_loss:0.2705  g_loss:2.5734
# 1/1 [==============================] - 0s 18ms/step
# epoch:351  d_loss:0.3774  g_loss:2.4662
# 1/1 [==============================] - 0s 18ms/step
# epoch:352  d_loss:0.3636  g_loss:2.1366
# 1/1 [==============================] - 0s 18ms/step
# epoch:353  d_loss:0.3545  g_loss:2.0980
# 1/1 [==============================] - 0s 18ms/step
# epoch:354  d_loss:0.2362  g_loss:2.8222
# 1/1 [==============================] - 0s 17ms/step
# epoch:355  d_loss:0.4776  g_loss:2.9331
# 1/1 [==============================] - 0s 20ms/step
# epoch:356  d_loss:0.4762  g_loss:2.1936
# 1/1 [==============================] - 0s 18ms/step
# epoch:357  d_loss:0.3734  g_loss:2.5481
# 1/1 [==============================] - 0s 18ms/step
# epoch:358  d_loss:0.3462  g_loss:2.5192
# 1/1 [==============================] - 0s 19ms/step
# epoch:359  d_loss:0.3285  g_loss:2.8188
# 1/1 [==============================] - 0s 18ms/step
# epoch:360  d_loss:0.4290  g_loss:2.3741
# 1/1 [==============================] - 0s 19ms/step
# epoch:361  d_loss:0.6292  g_loss:2.4510
# 1/1 [==============================] - 0s 20ms/step
# epoch:362  d_loss:0.5894  g_loss:1.8959
# 1/1 [==============================] - 0s 18ms/step
# epoch:363  d_loss:0.2468  g_loss:2.6445
# 1/1 [==============================] - 0s 18ms/step
# epoch:364  d_loss:0.3156  g_loss:3.0580
# 1/1 [==============================] - 0s 17ms/step
# epoch:365  d_loss:0.5799  g_loss:2.3138
# 1/1 [==============================] - 0s 18ms/step
# epoch:366  d_loss:0.4764  g_loss:2.0444
# 1/1 [==============================] - 0s 19ms/step
# epoch:367  d_loss:0.4042  g_loss:1.8135
# 1/1 [==============================] - 0s 20ms/step
# epoch:368  d_loss:0.4015  g_loss:1.8857
# 1/1 [==============================] - 0s 18ms/step
# epoch:369  d_loss:0.5455  g_loss:2.4323
# 1/1 [==============================] - 0s 17ms/step
# epoch:370  d_loss:0.4335  g_loss:3.0941
# 1/1 [==============================] - 0s 21ms/step
# epoch:371  d_loss:0.4699  g_loss:2.3199
# 1/1 [==============================] - 0s 18ms/step
# epoch:372  d_loss:0.4195  g_loss:1.8147
# 1/1 [==============================] - 0s 17ms/step
# epoch:373  d_loss:0.4634  g_loss:1.9265
# 1/1 [==============================] - 0s 18ms/step
# epoch:374  d_loss:0.4505  g_loss:2.1216
# 1/1 [==============================] - 0s 21ms/step
# epoch:375  d_loss:0.3740  g_loss:1.7466
# 1/1 [==============================] - 0s 20ms/step
# epoch:376  d_loss:0.5494  g_loss:2.1737
# 1/1 [==============================] - 0s 18ms/step
# epoch:377  d_loss:0.4035  g_loss:2.1048
# 1/1 [==============================] - 0s 18ms/step
# epoch:378  d_loss:0.4187  g_loss:2.3850
# 1/1 [==============================] - 0s 20ms/step
# epoch:379  d_loss:0.3537  g_loss:2.3132
# 1/1 [==============================] - 0s 19ms/step
# epoch:380  d_loss:0.4216  g_loss:2.7907
# 1/1 [==============================] - 0s 20ms/step
# epoch:381  d_loss:0.5632  g_loss:2.3335
# 1/1 [==============================] - 0s 19ms/step
# epoch:382  d_loss:0.4887  g_loss:1.6148
# 1/1 [==============================] - 0s 19ms/step
# epoch:383  d_loss:0.4325  g_loss:1.7782
# 1/1 [==============================] - 0s 18ms/step
# epoch:384  d_loss:0.3961  g_loss:1.9484
# 1/1 [==============================] - 0s 18ms/step
# epoch:385  d_loss:0.3862  g_loss:2.4500
# 1/1 [==============================] - 0s 19ms/step
# epoch:386  d_loss:0.4258  g_loss:2.1095
# 1/1 [==============================] - 0s 18ms/step
# epoch:387  d_loss:0.4582  g_loss:1.6024
# 1/1 [==============================] - 0s 18ms/step
# epoch:388  d_loss:0.5314  g_loss:1.6185
# 1/1 [==============================] - 0s 18ms/step
# epoch:389  d_loss:0.4219  g_loss:1.6476
# 1/1 [==============================] - 0s 18ms/step
# epoch:390  d_loss:0.4234  g_loss:2.0968
# 1/1 [==============================] - 0s 17ms/step
# epoch:391  d_loss:0.3250  g_loss:2.3897
# 1/1 [==============================] - 0s 18ms/step
# epoch:392  d_loss:0.5463  g_loss:2.3458
# 1/1 [==============================] - 0s 18ms/step
# epoch:393  d_loss:0.4654  g_loss:1.8108
# 1/1 [==============================] - 0s 18ms/step
# epoch:394  d_loss:0.4435  g_loss:1.4601
# 1/1 [==============================] - 0s 19ms/step
# epoch:395  d_loss:0.3901  g_loss:1.9988
# 1/1 [==============================] - 0s 17ms/step
# epoch:396  d_loss:0.4153  g_loss:2.4807
# 1/1 [==============================] - 0s 18ms/step
# epoch:397  d_loss:0.4837  g_loss:2.1996
# 1/1 [==============================] - 0s 18ms/step
# epoch:398  d_loss:0.3465  g_loss:2.2128
# 1/1 [==============================] - 0s 19ms/step
# epoch:399  d_loss:0.3418  g_loss:2.0322
# 1/1 [==============================] - 0s 22ms/step
# epoch:400  d_loss:0.3336  g_loss:1.9048
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# epoch:401  d_loss:0.3622  g_loss:1.9605
# 1/1 [==============================] - 0s 18ms/step
# epoch:402  d_loss:0.3868  g_loss:2.0678
# 1/1 [==============================] - 0s 18ms/step
# epoch:403  d_loss:0.2415  g_loss:2.9896
# 1/1 [==============================] - 0s 19ms/step
# epoch:404  d_loss:0.2867  g_loss:2.5946
# 1/1 [==============================] - 0s 17ms/step
# epoch:405  d_loss:0.3685  g_loss:1.8382
# 1/1 [==============================] - 0s 19ms/step
# epoch:406  d_loss:0.3509  g_loss:1.5107
# 1/1 [==============================] - 0s 18ms/step
# epoch:407  d_loss:0.4172  g_loss:1.6678
# 1/1 [==============================] - 0s 18ms/step
# epoch:408  d_loss:0.3466  g_loss:1.9519
# 1/1 [==============================] - 0s 20ms/step
# epoch:409  d_loss:0.2624  g_loss:3.1788
# 1/1 [==============================] - 0s 19ms/step
# epoch:410  d_loss:0.3847  g_loss:2.8527
# 1/1 [==============================] - 0s 19ms/step
# epoch:411  d_loss:0.3543  g_loss:2.5838
# 1/1 [==============================] - 0s 19ms/step
# epoch:412  d_loss:0.2735  g_loss:2.2135
# 1/1 [==============================] - 0s 18ms/step
# epoch:413  d_loss:0.3496  g_loss:2.0211
# 1/1 [==============================] - 0s 19ms/step
# epoch:414  d_loss:0.3195  g_loss:1.9382
# 1/1 [==============================] - 0s 18ms/step
# epoch:415  d_loss:0.4532  g_loss:1.9065
# 1/1 [==============================] - 0s 18ms/step
# epoch:416  d_loss:0.2336  g_loss:2.2902
# 1/1 [==============================] - 0s 21ms/step
# epoch:417  d_loss:0.2805  g_loss:2.3475
# 1/1 [==============================] - 0s 17ms/step
# epoch:418  d_loss:0.3217  g_loss:2.3700
# 1/1 [==============================] - 0s 18ms/step
# epoch:419  d_loss:0.3306  g_loss:1.7668
# 1/1 [==============================] - 0s 19ms/step
# epoch:420  d_loss:0.3610  g_loss:1.5762
# 1/1 [==============================] - 0s 18ms/step
# epoch:421  d_loss:0.3034  g_loss:2.1044
# 1/1 [==============================] - 0s 17ms/step
# epoch:422  d_loss:0.2877  g_loss:2.2819
# 1/1 [==============================] - 0s 18ms/step
# epoch:423  d_loss:0.2964  g_loss:2.3918
# 1/1 [==============================] - 0s 17ms/step
# epoch:424  d_loss:0.2927  g_loss:2.5810
# 1/1 [==============================] - 0s 17ms/step
# epoch:425  d_loss:0.2201  g_loss:2.6255
# 1/1 [==============================] - 0s 19ms/step
# epoch:426  d_loss:0.3577  g_loss:2.1826
# 1/1 [==============================] - 0s 17ms/step
# epoch:427  d_loss:0.3504  g_loss:1.8238
# 1/1 [==============================] - 0s 19ms/step
# epoch:428  d_loss:0.3109  g_loss:1.7782
# 1/1 [==============================] - 0s 20ms/step
# epoch:429  d_loss:0.3713  g_loss:2.2035
# 1/1 [==============================] - 0s 18ms/step
# epoch:430  d_loss:0.2658  g_loss:2.6346
# 1/1 [==============================] - 0s 18ms/step
# epoch:431  d_loss:0.2803  g_loss:2.4021
# 1/1 [==============================] - 0s 19ms/step
# epoch:432  d_loss:0.3135  g_loss:2.1191
# 1/1 [==============================] - 0s 18ms/step
# epoch:433  d_loss:0.4033  g_loss:1.9576
# 1/1 [==============================] - 0s 19ms/step
# epoch:434  d_loss:0.3396  g_loss:2.0620
# 1/1 [==============================] - 0s 18ms/step
# epoch:435  d_loss:0.3119  g_loss:2.2211
# 1/1 [==============================] - 0s 19ms/step
# epoch:436  d_loss:0.3755  g_loss:1.8725
# 1/1 [==============================] - 0s 19ms/step
# epoch:437  d_loss:0.3070  g_loss:2.1708
# 1/1 [==============================] - 0s 19ms/step
# epoch:438  d_loss:0.3656  g_loss:2.6024
# 1/1 [==============================] - 0s 17ms/step
# epoch:439  d_loss:0.2073  g_loss:3.2014
# 1/1 [==============================] - 0s 18ms/step
# epoch:440  d_loss:0.3331  g_loss:2.8985
# 1/1 [==============================] - 0s 18ms/step
# epoch:441  d_loss:0.2076  g_loss:2.6873
# 1/1 [==============================] - 0s 18ms/step
# epoch:442  d_loss:0.3973  g_loss:1.7133
# 1/1 [==============================] - 0s 20ms/step
# epoch:443  d_loss:0.3290  g_loss:1.3785
# 1/1 [==============================] - 0s 19ms/step
# epoch:444  d_loss:0.2932  g_loss:1.6428
# 1/1 [==============================] - 0s 18ms/step
# epoch:445  d_loss:0.3062  g_loss:2.0654
# 1/1 [==============================] - 0s 18ms/step
# epoch:446  d_loss:0.3125  g_loss:2.4833
# 1/1 [==============================] - 0s 19ms/step
# epoch:447  d_loss:0.2455  g_loss:2.9417
# 1/1 [==============================] - 0s 18ms/step
# epoch:448  d_loss:0.3038  g_loss:2.8432
# 1/1 [==============================] - 0s 18ms/step
# epoch:449  d_loss:0.2887  g_loss:2.6401
# 1/1 [==============================] - 0s 18ms/step
# epoch:450  d_loss:0.4372  g_loss:1.8467
# 1/1 [==============================] - 0s 19ms/step
# epoch:451  d_loss:0.3396  g_loss:2.1592
# 1/1 [==============================] - 0s 18ms/step
# epoch:452  d_loss:0.3027  g_loss:2.7307
# 1/1 [==============================] - 0s 18ms/step
# epoch:453  d_loss:0.3334  g_loss:2.6953
# 1/1 [==============================] - 0s 17ms/step
# epoch:454  d_loss:0.3298  g_loss:3.0699
# 1/1 [==============================] - 0s 17ms/step
# epoch:455  d_loss:0.3911  g_loss:2.1060
# 1/1 [==============================] - 0s 18ms/step
# epoch:456  d_loss:0.3495  g_loss:2.0749
# 1/1 [==============================] - 0s 19ms/step
# epoch:457  d_loss:0.2881  g_loss:2.2440
# 1/1 [==============================] - 0s 18ms/step
# epoch:458  d_loss:0.2395  g_loss:2.3044
# 1/1 [==============================] - 0s 19ms/step
# epoch:459  d_loss:0.2801  g_loss:2.5145
# 1/1 [==============================] - 0s 17ms/step
# epoch:460  d_loss:0.3066  g_loss:2.3045
# 1/1 [==============================] - 0s 18ms/step
# epoch:461  d_loss:0.2386  g_loss:2.8578
# 1/1 [==============================] - 0s 18ms/step
# epoch:462  d_loss:0.2322  g_loss:2.7922
# 1/1 [==============================] - 0s 19ms/step
# epoch:463  d_loss:0.2185  g_loss:2.3696
# 1/1 [==============================] - 0s 19ms/step
# epoch:464  d_loss:0.3364  g_loss:2.3255
# 1/1 [==============================] - 0s 18ms/step
# epoch:465  d_loss:0.2491  g_loss:1.9962
# 1/1 [==============================] - 0s 19ms/step
# epoch:466  d_loss:0.1834  g_loss:2.5785
# 1/1 [==============================] - 0s 18ms/step
# epoch:467  d_loss:0.3847  g_loss:2.7512
# 1/1 [==============================] - 0s 18ms/step
# epoch:468  d_loss:0.2160  g_loss:3.4658
# 1/1 [==============================] - 0s 18ms/step
# epoch:469  d_loss:0.3253  g_loss:3.1568
# 1/1 [==============================] - 0s 17ms/step
# epoch:470  d_loss:0.3551  g_loss:2.7655
# 1/1 [==============================] - 0s 18ms/step
# epoch:471  d_loss:0.2853  g_loss:2.4835
# 1/1 [==============================] - 0s 19ms/step
# epoch:472  d_loss:0.2674  g_loss:1.9155
# 1/1 [==============================] - 0s 18ms/step
# epoch:473  d_loss:0.2851  g_loss:2.2860
# 1/1 [==============================] - 0s 19ms/step
# epoch:474  d_loss:0.1753  g_loss:2.6478
# 1/1 [==============================] - 0s 18ms/step
# epoch:475  d_loss:0.2638  g_loss:2.8641
# 1/1 [==============================] - 0s 18ms/step
# epoch:476  d_loss:0.2216  g_loss:3.2281
# 1/1 [==============================] - 0s 18ms/step
# epoch:477  d_loss:0.2449  g_loss:2.6563
# 1/1 [==============================] - 0s 19ms/step
# epoch:478  d_loss:0.2024  g_loss:2.6015
# 1/1 [==============================] - 0s 17ms/step
# epoch:479  d_loss:0.1843  g_loss:2.6077
# 1/1 [==============================] - 0s 19ms/step
# epoch:480  d_loss:0.1512  g_loss:3.1209
# 1/1 [==============================] - 0s 18ms/step
# epoch:481  d_loss:0.2323  g_loss:3.3165
# 1/1 [==============================] - 0s 17ms/step
# epoch:482  d_loss:0.2662  g_loss:2.8474
# 1/1 [==============================] - 0s 19ms/step
# epoch:483  d_loss:0.2417  g_loss:2.5079
# 1/1 [==============================] - 0s 19ms/step
# epoch:484  d_loss:0.3500  g_loss:2.4895
# 1/1 [==============================] - 0s 19ms/step
# epoch:485  d_loss:0.2934  g_loss:2.4702
# 1/1 [==============================] - 0s 18ms/step
# epoch:486  d_loss:0.3043  g_loss:2.1117
# 1/1 [==============================] - 0s 18ms/step
# epoch:487  d_loss:0.1557  g_loss:3.3210
# 1/1 [==============================] - 0s 18ms/step
# epoch:488  d_loss:0.2863  g_loss:3.0358
# 1/1 [==============================] - 0s 19ms/step
# epoch:489  d_loss:0.3340  g_loss:2.5928
# 1/1 [==============================] - 0s 18ms/step
# epoch:490  d_loss:0.2357  g_loss:2.5846
# 1/1 [==============================] - 0s 17ms/step
# epoch:491  d_loss:0.2642  g_loss:2.2794
# 1/1 [==============================] - 0s 17ms/step
# epoch:492  d_loss:0.2645  g_loss:2.4562
# 1/1 [==============================] - 0s 19ms/step
# epoch:493  d_loss:0.2163  g_loss:3.7120
# 1/1 [==============================] - 0s 19ms/step
# epoch:494  d_loss:0.5235  g_loss:2.6584
# 1/1 [==============================] - 0s 20ms/step
# epoch:495  d_loss:0.3706  g_loss:1.9686
# 1/1 [==============================] - 0s 19ms/step
# epoch:496  d_loss:0.2654  g_loss:2.4343
# 1/1 [==============================] - 0s 25ms/step
# epoch:497  d_loss:0.4305  g_loss:2.0540
# 1/1 [==============================] - 0s 18ms/step
# epoch:498  d_loss:0.3852  g_loss:2.6707
# 1/1 [==============================] - 0s 17ms/step
# epoch:499  d_loss:0.2272  g_loss:3.4890
# 1/1 [==============================] - 0s 17ms/step
# epoch:500  d_loss:0.3542  g_loss:2.3866
# 1/1 [==============================] - 0s 18ms/step
# epoch:501  d_loss:0.3236  g_loss:2.2927
# 1/1 [==============================] - 0s 18ms/step
# epoch:502  d_loss:0.3971  g_loss:2.0620
# 1/1 [==============================] - 0s 18ms/step
# epoch:503  d_loss:0.2857  g_loss:2.0590
# 1/1 [==============================] - 0s 19ms/step
# epoch:504  d_loss:0.4645  g_loss:1.9475
# 1/1 [==============================] - 0s 19ms/step
# epoch:505  d_loss:0.4188  g_loss:2.0770
# 1/1 [==============================] - 0s 19ms/step
# epoch:506  d_loss:0.3509  g_loss:1.9663
# 1/1 [==============================] - 0s 22ms/step
# epoch:507  d_loss:0.2537  g_loss:2.2007
# 1/1 [==============================] - 0s 18ms/step
# epoch:508  d_loss:0.4130  g_loss:2.3599
# 1/1 [==============================] - 0s 22ms/step
# epoch:509  d_loss:0.2212  g_loss:2.1928
# 1/1 [==============================] - 0s 20ms/step
# epoch:510  d_loss:0.4534  g_loss:2.2776
# 1/1 [==============================] - 0s 17ms/step
# epoch:511  d_loss:0.2379  g_loss:2.6766
# ...
# epoch:1829  d_loss:0.6869  g_loss:1.5430
# 1/1 [==============================] - 0s 18ms/step
# epoch:1830  d_loss:0.6085  g_loss:1.2659
# 1/1 [==============================] - 0s 19ms/step
# epoch:1831  d_loss:0.5078  g_loss:1.5532
# 1/1 [==============================] - 0s 20ms/step
# epoch:1832  d_loss:0.5812  g_loss:1.4082
# 1/1 [==============================] - 0s 17ms/step
# epoch:1833  d_loss:0.5950  g_loss:1.2965
# 1/1 [==============================] - 0s 19ms/step
# epoch:1834  d_loss:0.6053  g_loss:1.4685
# 1/1 [==============================] - 0s 18ms/step
# epoch:1835  d_loss:0.4302  g_loss:1.8015
# 1/1 [==============================] - 0s 19ms/step
# epoch:1836  d_loss:0.4553  g_loss:1.9698
# 1/1 [==============================] - 0s 19ms/step
# epoch:1837  d_loss:0.4598  g_loss:1.9538
# 1/1 [==============================] - 0s 23ms/step
# epoch:1838  d_loss:0.4877  g_loss:1.6099
# 1/1 [==============================] - 0s 17ms/step
# epoch:1839  d_loss:0.5139  g_loss:1.6059
# 1/1 [==============================] - 0s 17ms/step
# epoch:1840  d_loss:0.4167  g_loss:1.8545
# 1/1 [==============================] - 0s 18ms/step
# epoch:1841  d_loss:0.3439  g_loss:1.8084
# 1/1 [==============================] - 0s 18ms/step
# epoch:1842  d_loss:0.5232  g_loss:1.4398
# 1/1 [==============================] - 0s 17ms/step
# epoch:1843  d_loss:0.4970  g_loss:1.5290
# 1/1 [==============================] - 0s 17ms/step
# epoch:1844  d_loss:0.4345  g_loss:1.6074
# 1/1 [==============================] - 0s 21ms/step
# epoch:1845  d_loss:0.5436  g_loss:2.1235
# 1/1 [==============================] - 0s 19ms/step
# epoch:1846  d_loss:0.4620  g_loss:1.8819
# 1/1 [==============================] - 0s 22ms/step
# epoch:1847  d_loss:0.3818  g_loss:1.7665
# 1/1 [==============================] - 0s 18ms/step
# epoch:1848  d_loss:0.5711  g_loss:1.6272
# 1/1 [==============================] - 0s 18ms/step
# epoch:1849  d_loss:0.5512  g_loss:1.6934
# 1/1 [==============================] - 0s 18ms/step
# epoch:1850  d_loss:0.5011  g_loss:1.4589
# 1/1 [==============================] - 0s 18ms/step
# epoch:1851  d_loss:0.5639  g_loss:1.4914
# 1/1 [==============================] - 0s 19ms/step
# epoch:1852  d_loss:0.4395  g_loss:2.0353
# 1/1 [==============================] - 0s 17ms/step
# epoch:1853  d_loss:0.5145  g_loss:1.7984
# 1/1 [==============================] - 0s 18ms/step
# epoch:1854  d_loss:0.4640  g_loss:2.0874
# 1/1 [==============================] - 0s 17ms/step
# epoch:1855  d_loss:0.4920  g_loss:1.8647
# 1/1 [==============================] - 0s 17ms/step
# epoch:1856  d_loss:0.5765  g_loss:1.9155
# 1/1 [==============================] - 0s 18ms/step
# epoch:1857  d_loss:0.5170  g_loss:1.9208
# 1/1 [==============================] - 0s 17ms/step
# epoch:1858  d_loss:0.6459  g_loss:1.3866
# 1/1 [==============================] - 0s 19ms/step
# epoch:1859  d_loss:0.5699  g_loss:1.3093
# 1/1 [==============================] - 0s 18ms/step
# epoch:1860  d_loss:0.5795  g_loss:1.4089
# 1/1 [==============================] - 0s 18ms/step
# epoch:1861  d_loss:0.4958  g_loss:1.3801
# 1/1 [==============================] - 0s 19ms/step
# epoch:1862  d_loss:0.5721  g_loss:1.6142
# 1/1 [==============================] - 0s 19ms/step
# epoch:1863  d_loss:0.7454  g_loss:1.5348
# 1/1 [==============================] - 0s 19ms/step
# epoch:1864  d_loss:0.5114  g_loss:1.8594
# 1/1 [==============================] - 0s 19ms/step
# epoch:1865  d_loss:0.6791  g_loss:1.5085
# 1/1 [==============================] - 0s 17ms/step
# epoch:1866  d_loss:0.5884  g_loss:1.4867
# 1/1 [==============================] - 0s 19ms/step
# epoch:1867  d_loss:0.4723  g_loss:1.3358
# 1/1 [==============================] - 0s 19ms/step
# epoch:1868  d_loss:0.4076  g_loss:1.6913
# 1/1 [==============================] - 0s 19ms/step
# epoch:1869  d_loss:0.4511  g_loss:1.5921
# 1/1 [==============================] - 0s 20ms/step
# epoch:1870  d_loss:0.5224  g_loss:1.6919
# 1/1 [==============================] - 0s 20ms/step
# epoch:1871  d_loss:0.5773  g_loss:1.4623
# 1/1 [==============================] - 0s 20ms/step
# epoch:1872  d_loss:0.4973  g_loss:1.4862
# 1/1 [==============================] - 0s 18ms/step
# epoch:1873  d_loss:0.5199  g_loss:1.7314
# 1/1 [==============================] - 0s 19ms/step
# epoch:1874  d_loss:0.7260  g_loss:1.4237
# 1/1 [==============================] - 0s 19ms/step
# epoch:1875  d_loss:0.5144  g_loss:1.2428
# 1/1 [==============================] - 0s 19ms/step
# epoch:1876  d_loss:0.4431  g_loss:1.3478
# 1/1 [==============================] - 0s 19ms/step
# epoch:1877  d_loss:0.5536  g_loss:1.4467
# 1/1 [==============================] - 0s 20ms/step
# epoch:1878  d_loss:0.4153  g_loss:1.5479
# 1/1 [==============================] - 0s 19ms/step
# epoch:1879  d_loss:0.5534  g_loss:1.4285
# 1/1 [==============================] - 0s 19ms/step
# epoch:1880  d_loss:0.4813  g_loss:1.5230
# 1/1 [==============================] - 0s 19ms/step
# epoch:1881  d_loss:0.5734  g_loss:1.2912
# 1/1 [==============================] - 0s 19ms/step
# epoch:1882  d_loss:0.4304  g_loss:1.5891
# 1/1 [==============================] - 0s 18ms/step
# epoch:1883  d_loss:0.4903  g_loss:1.7508
# 1/1 [==============================] - 0s 17ms/step
# epoch:1884  d_loss:0.5640  g_loss:1.6547
# 1/1 [==============================] - 0s 17ms/step
# epoch:1885  d_loss:0.4523  g_loss:1.7548
# 1/1 [==============================] - 0s 17ms/step
# epoch:1886  d_loss:0.6429  g_loss:1.4404
# 1/1 [==============================] - 0s 20ms/step
# epoch:1887  d_loss:0.6149  g_loss:1.0662
# 1/1 [==============================] - 0s 18ms/step
# epoch:1888  d_loss:0.5002  g_loss:1.1619
# 1/1 [==============================] - 0s 17ms/step
# epoch:1889  d_loss:0.5142  g_loss:1.4677
# 1/1 [==============================] - 0s 18ms/step
# epoch:1890  d_loss:0.4685  g_loss:1.7688
# 1/1 [==============================] - 0s 18ms/step
# epoch:1891  d_loss:0.5792  g_loss:1.5437
# 1/1 [==============================] - 0s 19ms/step
# epoch:1892  d_loss:0.5125  g_loss:1.7158
# 1/1 [==============================] - 0s 19ms/step
# epoch:1893  d_loss:0.5831  g_loss:1.4840
# 1/1 [==============================] - 0s 19ms/step
# epoch:1894  d_loss:0.5387  g_loss:1.4004
# 1/1 [==============================] - 0s 19ms/step
# epoch:1895  d_loss:0.5972  g_loss:1.3733
# 1/1 [==============================] - 0s 19ms/step
# epoch:1896  d_loss:0.5844  g_loss:1.5037
# 1/1 [==============================] - 0s 19ms/step
# epoch:1897  d_loss:0.4719  g_loss:1.8017
# 1/1 [==============================] - 0s 18ms/step
# epoch:1898  d_loss:0.5368  g_loss:1.6520
# 1/1 [==============================] - 0s 18ms/step
# epoch:1899  d_loss:0.4736  g_loss:1.6138
# 1/1 [==============================] - 0s 19ms/step
# epoch:1900  d_loss:0.4726  g_loss:1.5592
# 1/1 [==============================] - 0s 20ms/step
# epoch:1901  d_loss:0.6093  g_loss:1.4199
# 1/1 [==============================] - 0s 19ms/step
# epoch:1902  d_loss:0.4257  g_loss:1.3177
# 1/1 [==============================] - 0s 18ms/step
# epoch:1903  d_loss:0.4675  g_loss:1.6021
# 1/1 [==============================] - 0s 18ms/step
# epoch:1904  d_loss:0.5623  g_loss:1.7641
# 1/1 [==============================] - 0s 19ms/step
# epoch:1905  d_loss:0.5160  g_loss:1.4458
# 1/1 [==============================] - 0s 17ms/step
# epoch:1906  d_loss:0.4201  g_loss:1.7788
# 1/1 [==============================] - 0s 20ms/step
# epoch:1907  d_loss:0.5061  g_loss:1.5908
# 1/1 [==============================] - 0s 17ms/step
# epoch:1908  d_loss:0.5525  g_loss:1.4189
# 1/1 [==============================] - 0s 18ms/step
# epoch:1909  d_loss:0.4794  g_loss:1.4287
# 1/1 [==============================] - 0s 21ms/step
# epoch:1910  d_loss:0.4900  g_loss:1.5172
# 1/1 [==============================] - 0s 18ms/step
# epoch:1911  d_loss:0.4367  g_loss:1.5282
# 1/1 [==============================] - 0s 19ms/step
# epoch:1912  d_loss:0.5120  g_loss:1.8708
# 1/1 [==============================] - 0s 20ms/step
# epoch:1913  d_loss:0.5834  g_loss:1.5293
# 1/1 [==============================] - 0s 22ms/step
# epoch:1914  d_loss:0.4797  g_loss:1.6531
# 1/1 [==============================] - 0s 18ms/step
# epoch:1915  d_loss:0.6116  g_loss:1.3799
# 1/1 [==============================] - 0s 19ms/step
# epoch:1916  d_loss:0.4351  g_loss:1.5157
# 1/1 [==============================] - 0s 20ms/step
# epoch:1917  d_loss:0.5335  g_loss:1.4534
# 1/1 [==============================] - 0s 18ms/step
# epoch:1918  d_loss:0.4021  g_loss:1.6191
# 1/1 [==============================] - 0s 18ms/step
# epoch:1919  d_loss:0.4606  g_loss:1.7422
# 1/1 [==============================] - 0s 20ms/step
# epoch:1920  d_loss:0.7123  g_loss:1.9413
# 1/1 [==============================] - 0s 19ms/step
# epoch:1921  d_loss:0.6011  g_loss:1.9701
# 1/1 [==============================] - 0s 19ms/step
# epoch:1922  d_loss:0.5966  g_loss:1.6466
# 1/1 [==============================] - 0s 17ms/step
# epoch:1923  d_loss:0.8106  g_loss:1.2661
# 1/1 [==============================] - 0s 18ms/step
# epoch:1924  d_loss:0.8276  g_loss:0.8115
# 1/1 [==============================] - 0s 18ms/step
# epoch:1925  d_loss:0.5932  g_loss:0.8748
# 1/1 [==============================] - 0s 21ms/step
# epoch:1926  d_loss:0.6294  g_loss:1.1015
# 1/1 [==============================] - 0s 19ms/step
# epoch:1927  d_loss:0.5287  g_loss:1.2290
# 1/1 [==============================] - 0s 19ms/step
# epoch:1928  d_loss:0.5361  g_loss:1.5498
# 1/1 [==============================] - 0s 19ms/step
# epoch:1929  d_loss:0.4832  g_loss:1.9083
# 1/1 [==============================] - 0s 20ms/step
# epoch:1930  d_loss:0.5095  g_loss:1.6524
# 1/1 [==============================] - 0s 19ms/step
# epoch:1931  d_loss:0.5305  g_loss:1.7629
# 1/1 [==============================] - 0s 18ms/step
# epoch:1932  d_loss:0.5732  g_loss:1.3903
# 1/1 [==============================] - 0s 20ms/step
# epoch:1933  d_loss:0.4164  g_loss:1.2464
# 1/1 [==============================] - 0s 18ms/step
# epoch:1934  d_loss:0.5219  g_loss:1.3723
# 1/1 [==============================] - 0s 20ms/step
# epoch:1935  d_loss:0.6358  g_loss:1.2759
# 1/1 [==============================] - 0s 18ms/step
# epoch:1936  d_loss:0.6221  g_loss:1.5492
# 1/1 [==============================] - 0s 18ms/step
# epoch:1937  d_loss:0.5438  g_loss:1.6920
# 1/1 [==============================] - 0s 20ms/step
# epoch:1938  d_loss:0.4696  g_loss:1.8215
# 1/1 [==============================] - 0s 19ms/step
# epoch:1939  d_loss:0.5957  g_loss:1.7879
# 1/1 [==============================] - 0s 20ms/step
# epoch:1940  d_loss:0.5955  g_loss:1.6322
# 1/1 [==============================] - 0s 20ms/step
# epoch:1941  d_loss:0.5684  g_loss:1.3032
# 1/1 [==============================] - 0s 20ms/step
# epoch:1942  d_loss:0.4621  g_loss:1.2793
# 1/1 [==============================] - 0s 19ms/step
# epoch:1943  d_loss:0.3996  g_loss:1.3507
# 1/1 [==============================] - 0s 19ms/step
# epoch:1944  d_loss:0.5390  g_loss:1.4947
# 1/1 [==============================] - 0s 19ms/step
# epoch:1945  d_loss:0.4765  g_loss:1.5513
# 1/1 [==============================] - 0s 19ms/step
# epoch:1946  d_loss:0.4368  g_loss:1.5516
# 1/1 [==============================] - 0s 18ms/step
# epoch:1947  d_loss:0.3845  g_loss:1.8076
# 1/1 [==============================] - 0s 17ms/step
# epoch:1948  d_loss:0.4525  g_loss:1.7250
# 1/1 [==============================] - 0s 19ms/step
# epoch:1949  d_loss:0.4687  g_loss:1.6682
# 1/1 [==============================] - 0s 18ms/step
# epoch:1950  d_loss:0.4593  g_loss:1.7945
# 1/1 [==============================] - 0s 21ms/step
# epoch:1951  d_loss:0.3998  g_loss:1.6360
# 1/1 [==============================] - 0s 19ms/step
# epoch:1952  d_loss:0.5125  g_loss:1.4190
# 1/1 [==============================] - 0s 19ms/step
# epoch:1953  d_loss:0.4922  g_loss:1.6068
# 1/1 [==============================] - 0s 19ms/step
# epoch:1954  d_loss:0.6782  g_loss:1.5533
# 1/1 [==============================] - 0s 19ms/step
# epoch:1955  d_loss:0.4481  g_loss:1.5758
# 1/1 [==============================] - 0s 19ms/step
# epoch:1956  d_loss:0.4981  g_loss:1.7597
# 1/1 [==============================] - 0s 19ms/step
# epoch:1957  d_loss:0.5322  g_loss:1.8851
# 1/1 [==============================] - 0s 18ms/step
# epoch:1958  d_loss:0.6349  g_loss:1.2312
# 1/1 [==============================] - 0s 20ms/step
# epoch:1959  d_loss:0.6800  g_loss:1.1125
# 1/1 [==============================] - 0s 17ms/step
# epoch:1960  d_loss:0.5351  g_loss:1.4262
# 1/1 [==============================] - 0s 18ms/step
# epoch:1961  d_loss:0.5338  g_loss:1.7417
# 1/1 [==============================] - 0s 18ms/step
# epoch:1962  d_loss:0.5298  g_loss:1.9213
# 1/1 [==============================] - 0s 19ms/step
# epoch:1963  d_loss:0.3942  g_loss:1.9463
# 1/1 [==============================] - 0s 18ms/step
# epoch:1964  d_loss:0.4598  g_loss:1.8332
# 1/1 [==============================] - 0s 18ms/step
# epoch:1965  d_loss:0.4824  g_loss:1.6509
# 1/1 [==============================] - 0s 19ms/step
# epoch:1966  d_loss:0.6167  g_loss:1.6604
# 1/1 [==============================] - 0s 18ms/step
# epoch:1967  d_loss:0.6354  g_loss:1.2183
# 1/1 [==============================] - 0s 18ms/step
# epoch:1968  d_loss:0.5067  g_loss:1.3508
# 1/1 [==============================] - 0s 19ms/step
# epoch:1969  d_loss:0.6092  g_loss:1.4829
# 1/1 [==============================] - 0s 20ms/step
# epoch:1970  d_loss:0.5958  g_loss:1.7235
# 1/1 [==============================] - 0s 20ms/step
# epoch:1971  d_loss:0.5006  g_loss:1.9258
# 1/1 [==============================] - 0s 20ms/step
# epoch:1972  d_loss:0.5469  g_loss:1.4414
# 1/1 [==============================] - 0s 19ms/step
# epoch:1973  d_loss:0.6349  g_loss:1.4102
# 1/1 [==============================] - 0s 21ms/step
# epoch:1974  d_loss:0.5864  g_loss:1.3236
# 1/1 [==============================] - 0s 20ms/step
# epoch:1975  d_loss:0.4655  g_loss:1.2012
# 1/1 [==============================] - 0s 19ms/step
# epoch:1976  d_loss:0.5517  g_loss:1.4111
# 1/1 [==============================] - 0s 18ms/step
# epoch:1977  d_loss:0.5241  g_loss:1.5276
# 1/1 [==============================] - 0s 21ms/step
# epoch:1978  d_loss:0.4382  g_loss:1.8846
# 1/1 [==============================] - 0s 20ms/step
# epoch:1979  d_loss:0.5682  g_loss:1.5199
# 1/1 [==============================] - 0s 18ms/step
# epoch:1980  d_loss:0.7096  g_loss:1.5685
# 1/1 [==============================] - 0s 18ms/step
# epoch:1981  d_loss:0.5469  g_loss:1.2425
# 1/1 [==============================] - 0s 20ms/step
# epoch:1982  d_loss:0.5213  g_loss:1.2651
# 1/1 [==============================] - 0s 20ms/step
# epoch:1983  d_loss:0.6463  g_loss:1.3241
# 1/1 [==============================] - 0s 20ms/step
# epoch:1984  d_loss:0.5104  g_loss:1.5553
# 1/1 [==============================] - 0s 18ms/step
# epoch:1985  d_loss:0.6440  g_loss:1.2524
# 1/1 [==============================] - 0s 19ms/step
# epoch:1986  d_loss:0.6410  g_loss:1.1192
# 1/1 [==============================] - 0s 18ms/step
# epoch:1987  d_loss:0.6432  g_loss:1.2112
# 1/1 [==============================] - 0s 18ms/step
# epoch:1988  d_loss:0.4940  g_loss:1.3957
# 1/1 [==============================] - 0s 17ms/step
# epoch:1989  d_loss:0.5902  g_loss:1.6281
# 1/1 [==============================] - 0s 19ms/step
# epoch:1990  d_loss:0.5921  g_loss:1.2380
# 1/1 [==============================] - 0s 18ms/step
# epoch:1991  d_loss:0.6540  g_loss:1.1891
# 1/1 [==============================] - 0s 18ms/step
# epoch:1992  d_loss:0.5879  g_loss:1.1789
# 1/1 [==============================] - 0s 19ms/step
# epoch:1993  d_loss:0.5070  g_loss:1.0533
# 1/1 [==============================] - 0s 18ms/step
# epoch:1994  d_loss:0.5262  g_loss:1.2538
# 1/1 [==============================] - 0s 18ms/step
# epoch:1995  d_loss:0.4503  g_loss:1.4280
# 1/1 [==============================] - 0s 18ms/step
# epoch:1996  d_loss:0.3816  g_loss:1.6554
# 1/1 [==============================] - 0s 18ms/step
# epoch:1997  d_loss:0.4344  g_loss:1.2783
# 1/1 [==============================] - 0s 18ms/step
# epoch:1998  d_loss:0.5020  g_loss:1.5258
# 1/1 [==============================] - 0s 19ms/step
# epoch:1999  d_loss:0.5298  g_loss:1.3629
# 1/1 [==============================] - 0s 19ms/step
# epoch:2000  d_loss:0.4550  g_loss:1.4585
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더

# %% [markdown]
# ### 실습: 오토인코더 실습하기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
import matplotlib.pyplot as plt
import numpy as np

# MNIST 데이터셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분이 이어집니다. 
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인해 봅니다.
autoencoder.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 8)           584
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  # 테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)                     # 앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))                         # 출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):       # 랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1) 
   plt.imshow(X_test[image_idx].reshape(28, 28))   # 테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28)) # 오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2041 - val_loss: 0.1329
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1245 - val_loss: 0.1169
# Epoch 3/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1133 - val_loss: 0.1088
# Epoch 4/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1073 - val_loss: 0.1038
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1034 - val_loss: 0.1005
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1005 - val_loss: 0.0982
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0982 - val_loss: 0.0962
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0943
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0950 - val_loss: 0.0931
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0933
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0928 - val_loss: 0.0926
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0919 - val_loss: 0.0903
# Epoch 13/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0911 - val_loss: 0.0895
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0904 - val_loss: 0.0889
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0898 - val_loss: 0.0892
# Epoch 16/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0893 - val_loss: 0.0884
# Epoch 17/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0888 - val_loss: 0.0875
# Epoch 18/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0884 - val_loss: 0.0874
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0879 - val_loss: 0.0866
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0875 - val_loss: 0.0863
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0872 - val_loss: 0.0861
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0869 - val_loss: 0.0856
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0865 - val_loss: 0.0854
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0863 - val_loss: 0.0852
# Epoch 25/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0860 - val_loss: 0.0849
# Epoch 26/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0858 - val_loss: 0.0850
# Epoch 27/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0855 - val_loss: 0.0844
# Epoch 28/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0853 - val_loss: 0.0845
# Epoch 29/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0850 - val_loss: 0.0839
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0849 - val_loss: 0.0838
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0847 - val_loss: 0.0834
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0845 - val_loss: 0.0835
# Epoch 33/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0843 - val_loss: 0.0836
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0841 - val_loss: 0.0831
# Epoch 35/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0840 - val_loss: 0.0832
# Epoch 36/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0838 - val_loss: 0.0833
# Epoch 37/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0837 - val_loss: 0.0827
# Epoch 38/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0835 - val_loss: 0.0825
# Epoch 39/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0834 - val_loss: 0.0825
# Epoch 40/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0832 - val_loss: 0.0824
# Epoch 41/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0831 - val_loss: 0.0821
# Epoch 42/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0830 - val_loss: 0.0819
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0829 - val_loss: 0.0817
# Epoch 44/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0828 - val_loss: 0.0819
# Epoch 45/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0827 - val_loss: 0.0816
# Epoch 46/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0826 - val_loss: 0.0817
# Epoch 47/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0824 - val_loss: 0.0814
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0824 - val_loss: 0.0820
# Epoch 49/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0822 - val_loss: 0.0816
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0822 - val_loss: 0.0813
