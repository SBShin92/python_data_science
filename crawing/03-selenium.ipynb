# %%
# !pip install selenium
# !pip install webdriver-manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# %%
def set_chrome_driver(run_as_headless=False):  # 크롬드라이버 생성 함수
    chrome_options = webdriver.ChromeOptions()  # 드라이버 옵션 설정
    
    if run_as_headless:
        chrome_options.add_argument("--headless")  # 헤드리스 모드로 실행
    
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),
                            options=chrome_options)
    return driver

# %%
driver = set_chrome_driver()

# %% [markdown]
# ### 시나리오
# 1. 네이버 접속
# 2. 검색어 입력
# 3. 검색 버튼

# %%
driver.get("https://www.naver.com")

# %%
#  input#query, button.btn_search
from selenium.webdriver.common.by import By

input_search = driver.find_element(By.ID, "query")
input_search.send_keys("IPHONE")
btn_search = driver.find_element(By.CSS_SELECTOR, "button.btn_search")
btn_search.click()

driver.page_source
# Out:
# '<html lang="ko" data-useragent="mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/128.0.0.0 safari/537.36" data-platform="win32"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="IPHONE : 네이버 검색"> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'IPHONE\'의 네이버 검색 결과입니다."> <meta name="description" lang="ko" content="\'IPHONE\'의 네이버 검색 결과입니다."> <title>IPHONE : 네이버 검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver"><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_2408
# ...

# %%
driver = set_chrome_driver()
driver.get("https://naver.com")

driver.implicitly_wait(3)

btn_login = driver.find_element(By.CSS_SELECTOR, "#account > div > a")
btn_login.click()

driver.implicitly_wait(3)

input_login = driver.find_element(By.ID, "id")
input_login.send_keys("autoInputtedId")
input_pw = driver.find_element(By.ID, "pw")
input_pw.send_keys("1234")
# btn_login_submit = driver.find_element(By.XPATH, '//*[@id="log.login"]')
# btn_login_submit.click()
